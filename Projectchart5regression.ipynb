# %% [markdown]
# <a href="https://colab.research.google.com/github/Leenayesh/Leenayesh.github.io/blob/main/Projectchart5regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
Genderparityindex=pd.read_csv('ProjectChart4 (1).csv')
Urbanisationrate=pd.read_csv('UrbanisationRate1 (1).csv')

# %%
df1=Genderparityindex
df2=Urbanisationrate

# %%
df3 = pd.merge(df1, df2)
df3
# Out:
#          Country  Gender Parity Index   ...  date Urbanisation Rate
# 0        Namibia                  0.81  ...  2020            52.033
# 1         Rwanda                  0.81  ...  2020            17.432
# 2   South Africa                  0.78  ...  2020            67.354
# 3        Burundi                  0.77  ...  2020            13.708
# 4     Mozambique                  0.76  ...  2020            37.074
# 5       Zimbabwe                  0.73  ...  2020            32.242
# 6       Eswatini                  0.73  ...  2020            24.171
# 7         Zambia                  0.73  ...  2020            44.629
# 8     Madagascar                  0.73  ...  2020            38.534
# 9         Uganda                  0.72  ...  2020            24.954
# 10    Cape Verde                  0.72  ...  2020            66.652
# 11      Botswana                  0.72  ...  2020            70.877
# 12      Tanzania                  0.71  ...  2020            35.227
# ...

# %%
x = df3['Urbanisation Rate']
y = df3['Gender Parity Index ']

# %%
import seaborn as sns
sns.set()

# %%
sns.regplot(x='Urbanisation Rate',y='Gender Parity Index ', data = df3)
plt.title('Relationship between Urbanisation (2020) and Gender Parity Index(2021)')
# Out:
# Text(0.5, 1.0, 'Relationship between Urbanisation (2020) and Gender Parity Index(2021)')

# %%
from scipy.stats import linregress

# %%
slope, intercept, rvalue, pvalue, stderr = linregress(x=df3['Urbanisation Rate'], y=df3['Gender Parity Index '])

# %%
print('y = ',np.round(slope,2),' * x + ',np.round(intercept,2))
print('R² = ',np.round(rvalue**2,2))
# Out:
# y =  0.0  * x +  0.69
# R² =  0.0

# %%
df3.to_csv('ProjectMergedchartdata.csv')
