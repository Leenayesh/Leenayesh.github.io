# %% [markdown]
# <a href="https://colab.research.google.com/github/Leenayesh/Leenayesh.github.io/blob/main/Analytics_Homework_Excerpt_from_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First, we should install the World Bank API for rural population in subsaharan African countries.

# %%
import numpy as np 
import pandas as pd
import requests, json

# %%
countries=['AGO','BEN','BWA','BFA','BDI','CPV', 'CMR', 'CAF', 'TCD', 'COM', 'COG', 'COD','CIV', 'GNQ','ERI','SWZ', 'ETH', 'GAB', 'GMB', 'GIN','GNB','KEN', 'LSO', 'LBR', 'MDG','MWI', 'MLT','MRT','MUS','MOZ','NAM','NER','NGA','RWA','STP','SEN','SYC','SLE','SOM','ZAF','SSD','TZA','TGO','UGA','ZMB','ZWE']

# %%
data=[]
for country in countries:
  url='https://api.worldbank.org/v2/country/'+country+'/indicator/SP.RUR.TOTL.ZS?format=json'
  json_data=requests.get(url).json()[1]
  data.append(json_data)

# %%
flat_data=np.array(data).flatten()
df=pd.json_normalize(flat_data)
df
# Out:
#      countryiso3code  date  ...  country.id country.value
# 0                AGO  2020  ...          AO        Angola
# 1                AGO  2019  ...          AO        Angola
# 2                AGO  2018  ...          AO        Angola
# 3                AGO  2017  ...          AO        Angola
# 4                AGO  2016  ...          AO        Angola
# ...              ...   ...  ...         ...           ...
# 2295             ZWE  1975  ...          ZW      Zimbabwe
# 2296             ZWE  1974  ...          ZW      Zimbabwe
# 2297             ZWE  1973  ...          ZW      Zimbabwe
# 2298             ZWE  1972  ...          ZW      Zimbabwe
# 2299             ZWE  1971  ...          ZW      Zimbabwe
#
# [2300 rows x 10 columns]

# %%
df.to_csv("RuralPopulation.csv")

# %% [markdown]
# I sorted the csv file on excel by date and only kept 2019 values for each country. I rename it projectchart9plot

# %%
df1=pd.read_csv('/content/DP_LIVE_09012022145338938.csv')
df2=pd.read_csv('/content/projectchart9plot.csv')
df1
df1=df1.rename(columns = {'LOCATION':'countryiso3code'})

# %%
df3 = pd.merge(df1, df2)
df3.drop(df3.index[40], inplace=True)
df3.drop(df3.index[18], inplace=True)

df3
# Out:
#    countryiso3code  INDICATOR  ... Unnamed: 9               Unnamed: 10
# 0              ETH  VIOLWOMEN  ...         ET                  Ethiopia
# 1              MOZ  VIOLWOMEN  ...         MZ                Mozambique
# 2              NGA  VIOLWOMEN  ...         NG                   Nigeria
# 3              ZAF  VIOLWOMEN  ...         ZA              South Africa
# 4              TZA  VIOLWOMEN  ...         TZ                  Tanzania
# 5              ZMB  VIOLWOMEN  ...         ZM                    Zambia
# 6              AGO  VIOLWOMEN  ...         AO                    Angola
# 7              BEN  VIOLWOMEN  ...         BJ                     Benin
# 8              BWA  VIOLWOMEN  ...         BW                  Botswana
# 9              BFA  VIOLWOMEN  ...         BF              Burkina Faso
# 10             BDI  VIOLWOMEN  ...         BI                   Burundi
# 11             CMR  VIOLWOMEN  ...         CM                  Cameroon
# 12             CAF  VIOLWOMEN  ...         CF  Central African Republic
# 13             TCD  VIOLWOMEN  ...         TD                      Chad
# 14             COG  VIOLWOMEN  ...         CG               Congo, Rep.
# 15             CIV  VIOLWOMEN  ...         CI             Cote d'Ivoire
# 16             COD  VIOLWOMEN  ...         CD          Congo, Dem. Rep.
# 17             GNQ  VIOLWOMEN  ...         GQ         Equatorial Guinea
# 19             GAB  VIOLWOMEN  ...         GA                     Gabon
# 20             GMB  VIOLWOMEN  ...         GM               Gambia, The
# 21             GIN  VIOLWOMEN  ...         GN                    Guinea
# 22             GNB  VIOLWOMEN  ...         GW             Guinea-Bissau
# 23             KEN  VIOLWOMEN  ...         KE                     Kenya
# 24             LSO  VIOLWOMEN  ...         LS                   Lesotho
# 25             LBR  VIOLWOMEN  ...         LR                   Liberia
# 26             MDG  VIOLWOMEN  ...         MG                Madagascar
# 27             MWI  VIOLWOMEN  ...         MW                    Malawi
# 28             MRT  VIOLWOMEN  ...         MR                Mauritania
# 29             MUS  VIOLWOMEN  ...         MU                 Mauritius
# 30             NAM  VIOLWOMEN  ...        NaN                   Namibia
# 31             NER  VIOLWOMEN  ...         NE                     Niger
# 32             RWA  VIOLWOMEN  ...         RW                    Rwanda
# 33             SEN  VIOLWOMEN  ...         SN                   Senegal
# 34             SLE  VIOLWOMEN  ...         SL              Sierra Leone
# 35             SOM  VIOLWOMEN  ...         SO                   Somalia
# 36             SWZ  VIOLWOMEN  ...         SZ                  Eswatini
# 37             TGO  VIOLWOMEN  ...         TG                      Togo
# 38             UGA  VIOLWOMEN  ...         UG                    Uganda
# 39             ZWE  VIOLWOMEN  ...         ZW                  Zimbabwe
#
# [39 rows x 18 columns]

# %%
df3.to_csv("Projectplot9.csv")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
x = df3['rural population (% of total)']
y = df3['Value']
df3
# Out:
#    countryiso3code  INDICATOR  ... Unnamed: 9               Unnamed: 10
# 0              ETH  VIOLWOMEN  ...         ET                  Ethiopia
# 1              MOZ  VIOLWOMEN  ...         MZ                Mozambique
# 2              NGA  VIOLWOMEN  ...         NG                   Nigeria
# 3              ZAF  VIOLWOMEN  ...         ZA              South Africa
# 4              TZA  VIOLWOMEN  ...         TZ                  Tanzania
# 5              ZMB  VIOLWOMEN  ...         ZM                    Zambia
# 6              AGO  VIOLWOMEN  ...         AO                    Angola
# 7              BEN  VIOLWOMEN  ...         BJ                     Benin
# 8              BWA  VIOLWOMEN  ...         BW                  Botswana
# 9              BFA  VIOLWOMEN  ...         BF              Burkina Faso
# 10             BDI  VIOLWOMEN  ...         BI                   Burundi
# 11             CMR  VIOLWOMEN  ...         CM                  Cameroon
# 12             CAF  VIOLWOMEN  ...         CF  Central African Republic
# 13             TCD  VIOLWOMEN  ...         TD                      Chad
# 14             COG  VIOLWOMEN  ...         CG               Congo, Rep.
# 15             CIV  VIOLWOMEN  ...         CI             Cote d'Ivoire
# 16             COD  VIOLWOMEN  ...         CD          Congo, Dem. Rep.
# 17             GNQ  VIOLWOMEN  ...         GQ         Equatorial Guinea
# 19             GAB  VIOLWOMEN  ...         GA                     Gabon
# 20             GMB  VIOLWOMEN  ...         GM               Gambia, The
# 21             GIN  VIOLWOMEN  ...         GN                    Guinea
# 22             GNB  VIOLWOMEN  ...         GW             Guinea-Bissau
# 23             KEN  VIOLWOMEN  ...         KE                     Kenya
# 24             LSO  VIOLWOMEN  ...         LS                   Lesotho
# 25             LBR  VIOLWOMEN  ...         LR                   Liberia
# 26             MDG  VIOLWOMEN  ...         MG                Madagascar
# 27             MWI  VIOLWOMEN  ...         MW                    Malawi
# 28             MRT  VIOLWOMEN  ...         MR                Mauritania
# 29             MUS  VIOLWOMEN  ...         MU                 Mauritius
# 30             NAM  VIOLWOMEN  ...        NaN                   Namibia
# 31             NER  VIOLWOMEN  ...         NE                     Niger
# 32             RWA  VIOLWOMEN  ...         RW                    Rwanda
# 33             SEN  VIOLWOMEN  ...         SN                   Senegal
# 34             SLE  VIOLWOMEN  ...         SL              Sierra Leone
# 35             SOM  VIOLWOMEN  ...         SO                   Somalia
# 36             SWZ  VIOLWOMEN  ...         SZ                  Eswatini
# 37             TGO  VIOLWOMEN  ...         TG                      Togo
# 38             UGA  VIOLWOMEN  ...         UG                    Uganda
# 39             ZWE  VIOLWOMEN  ...         ZW                  Zimbabwe
#
# [39 rows x 18 columns]

# %%
sns.regplot(x='rural population (% of total)',y='Value', data = df3)
plt.title('Relationship between domestic violence laws and urbanisation')
plt.savefig("reg1.png")

# %%
from scipy.stats import linregress

# %%
slope, intercept, rvalue, pvalue, stderr = linregress(x=df3['rural population (% of total)'], y=df3['Value'])

# %%
print('y = ',np.round(slope,2),' * x + ',np.round(intercept,2))
print('R² = ',np.round(rvalue**2,2))
# Out:
# y =  -0.0  * x +  0.75
# R² =  0.05

# %%
df3.to_csv('ProjectChart9and10.csv')
